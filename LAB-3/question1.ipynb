# %%
#ASSIGNMENT-3-QUESTION-1
#2016UCP1103
#ABHISHEK TIBREWAL
#FEED-FORWARD BACK-PROPAGATION ALGORITHM
######################################################

# %%
import numpy as np
import math

# %%
def Activation_sigmoid(net):
    x=1/(1+(math.e**(-1*net)))
    return x

# %%
alpha=0.9   #Learning Rate
d=1       #Desired output

# %%
in_nodes=int(input("Enter # of input nodes:: "))
inp=list(map(float,input("Enter values of input nodes:: ").split()))
inp=[[i] for i in inp]
hide_nodes=int(input("Enter # of hidden nodes:: "))
inp=np.array(inp)

hide_weights=[]
for i in range(hide_nodes):
    print("Enter values of weights at hidden node",i+1,":: ")
    w=list(map(float,input().split()))
    w=[[i] for i in w]
    hide_weights.append(np.array(w))
print("Enter values of weights at output node:: ")
w=list(map(float,input().split()))
w=[[i] for i in w]
out_weights=np.array(w)
bias_hidden=list(map(float,input("Enter values of bias at hidden nodes:: ").split()))
bias_out=float(input("Enter values of bias at output nodes:: "))

print(inp)
print(hide_weights)
print(out_weights)
print(bias_hidden)
print(bias_out)
# Out:
# Enter # of input nodes:: 3
# Enter values of input nodes:: 1 0 1
# Enter # of hidden nodes:: 2
# Enter values of weights at hidden node 1 ::
# 0.2 0.4 -0.5
# Enter values of weights at hidden node 2 ::
# -0.3 0.1 0.2
# Enter values of weights at output node::
# -0.3 -0.2
# Enter values of bias at hidden nodes:: -0.4 0.2
# Enter values of bias at output nodes:: 0.1
# [[1.]
#  [0.]
#  [1.]]
# [array([[ 0.2],
#        [ 0.4],
#        [-0.5]]), array([[-0.3],
#        [ 0.1],
#        [ 0.2]])]
# [[-0.3]
#  [-0.2]]
# [-0.4, 0.2]
# 0.1

# %%
epoc=1000
for x in range(epoc):  
    print("EPOCH-",x+1)
    ##Feed-Forward for Hidden Layer
    hidden_inp=[]
    for i in range(hide_nodes):
        net=np.dot(np.transpose(hide_weights[i]),inp)
        net=net[0][0]
        net+=bias_hidden[i]
        out=Activation_sigmoid(net)
        hidden_inp.append([out])
    hidden_inp=np.array(hidden_inp)
    #print(hidden_inp)

    ##Feed-Forward for Output Layer
    net=np.dot(np.transpose(out_weights),hidden_inp)
    net=net[0][0]
    net+=bias_out
    out=Activation_sigmoid(net)
    #print(out)

    ##Back Propagation
    Error_out=out*(1-out)*(d-out)
    print("Error=",Error_out)
    if(Error_out<=0.001):
        break
    Error_hidden=[]
    for i in range(hide_nodes):
        err=hidden_inp[i][0]*(1-hidden_inp[i][0])*(Error_out*out_weights[i][0])
        Error_hidden.append(err)
    #print(Error_out)
    #print(Error_hidden)


    #weight update between hidden & output layer
    print("Weights at Output node::",end=" ")
    for i in range(hide_nodes):
        out_weights[i][0]+=(alpha*Error_out*hidden_inp[i][0])
        print(out_weights[i][0],end=" ")
    print("\n")
    #print(out_weights)


    #weight update between hidden & input layer
   
    for i in range(hide_nodes):
        print("Weights at Hidden node",i+1,"::",end=" ")
        for j in range(in_nodes):
            hide_weights[i][j][0]+=(alpha*Error_hidden[i]*inp[j][0]) 
            print(hide_weights[i][j][0],end=" ")
        print("\n")
    #print(hide_weights)

    #bias weight update for output layer
    bias_out+=(alpha*Error_out)
    print("Bias weight at Output node:: ",bias_out)

    #bias weight update for hidden layer
    for i in range(hide_nodes):
        print("Bias weight at Hidden node ",i+1 ,":: ",end=" ")
        bias_hidden[i]+=(alpha*Error_hidden[i])
        print(bias_hidden[i])
    print("\n")
# Out:
# EPOCH- 1
# Error= 0.1311690782143445
# Weights at Output node:: -0.26082884634154524 -0.13802506750700472
#
# Weights at Hidden node 1 :: 0.19214789423111006 0.4 -0.50785210576889
#
# Weights at Hidden node 2 :: -0.30588787655775207 0.1 0.19411212344224793
#
# Bias weight at Output node::  0.21805217039291008
# Bias weight at Hidden node  1 ::  -0.40785210576888997
# Bias weight at Hidden node  2 ::  0.19411212344224793
#
#
# EPOCH- 2
# Error= 0.1210753073978755
# Weights at Output node:: -0.225238843882119 -0.0812994426779621
#
# Weights at Hidden node 1 :: 0.18589688582870498 0.4 -0.5141031141712951
#
# Weights at Hidden node 2 :: -0.30964158229164446 0.1 0.19035841770835554
#
# Bias weight at Output node::  0.327019947050998
# Bias weight at Hidden node  1 ::  -0.4141031141712951
# Bias weight at Hidden node  2 ::  0.19035841770835554
#
#
# EPOCH- 3
# Error= 0.11053169435514751
# Weights at Output node:: -0.19315708319329994 -0.029793308628267436
#
# Weights at Hidden node 1 :: 0.18100122644838923 0.4 -0.5189987735516108
#
# Weights at Hidden node 2 :: -0.31166091811101293 0.1 0.18833908188898707
#
# Bias weight at Output node::  0.4264984719706308
# Bias weight at Hidden node  1 ::  -0.41899877355161086
# Bias weight at Hidden node  2 ::  0.18833908188898707
#
#
# EPOCH- 4
# Error= 0.10028659246282556
# Weights at Output node:: -0.16433783771911883 0.016802221943971254
#
# Weights at Hidden node 1 :: 0.17721200670568857 0.4 -0.5227879932943115
#
# Weights at Hidden node 2 :: -0.31233247876369624 0.1 0.18766752123630376
#
# Bias weight at Output node::  0.5167564051871738
# Bias weight at Hidden node  1 ::  -0.4227879932943115
# Bias weight at Hidden node  2 ::  0.18766752123630376
#
#
# EPOCH- 5
# Error= 0.09077512697601935
# Weights at Output node:: -0.13845332797836546 0.05893739339881124
#
# Weights at Hidden node 1 :: 0.17430594843713057 0.4 -0.5256940515628695
#
# Weights at Hidden node 2 :: -0.3119896437201524 0.1 0.1880103562798476
#
# Bias weight at Output node::  0.5984540194655912
# Bias weight at Hidden node  1 ::  -0.4256940515628695
# Bias weight at Hidden node  2 ::  0.1880103562798476
#
#
# EPOCH- 6
# Error= 0.08218950264911268
# Weights at Output node:: -0.11515636989375543 0.09710636857320451
#
# Weights at Hidden node 1 :: 0.17209628837719085 0.4 -0.5279037116228092
#
# Weights at Hidden node 2 :: -0.31090085222029373 0.1 0.1890991477797063
#
# Bias weight at Output node::  0.6724245718497925
# Bias weight at Hidden node  1 ::  -0.4279037116228092
# Bias weight at Hidden node  2 ::  0.1890991477797063
#
#
# EPOCH- 7
# Error= 0.07456647937437838
# Weights at Output node:: -0.09411605505962531 0.13178993837570874
#
# Weights at Hidden node 1 :: 0.1704329994076201 0.4 -0.5295670005923799
#
# Weights at Hidden node 2 :: -0.309273497459609 0.1 0.190726502540391
#
# Bias weight at Output node::  0.739534403286733
# Bias weight at Hidden node  1 ::  -0.42956700059237996
# Bias weight at Hidden node  2 ::  0.190726502540391
#
#
# EPOCH- 8
# Error= 0.06785773470072433
# Weights at Output node:: -0.07503426383072001 0.16342747680653796
#
# Weights at Hidden node 1 :: 0.16919822215234254 0.4 -0.5308017778476575
#
# Weights at Hidden node 2 :: -0.30726394847232374 0.1 0.19273605152767626
#
# Bias weight at Output node::  0.8006063645173849
# Bias weight at Hidden node  1 ::  -0.4308017778476575
# Bias weight at Hidden node  2 ::  0.19273605152767626
#
#
# EPOCH- 9
# Error= 0.06197624055227076
# Weights at Output node:: -0.0576507223934083 0.1924068151782073
#
# Weights at Hidden node 1 :: 0.16830036826765474 0.4 -0.5316996317323452
#
# Weights at Hidden node 2 :: -0.30498849007684053 0.1 0.19501150992315947
#
# Bias weight at Output node::  0.8563849810144286
# Bias weight at Hidden node  1 ::  -0.43169963173234527
# Bias weight at Hidden node  2 ::  0.19501150992315947
#
#
# EPOCH- 10
# Error= 0.056823165265399024
# Weights at Output node:: -0.041742088616914766 0.21906376941952124
#
# Weights at Hidden node 1 :: 0.1676685245763135 0.4 -0.5323314754236865
#
# Weights at Hidden node 2 :: -0.302532969682357 0.1 0.197467030317643
#
# Bias weight at Output node::  0.9075258297532878
# Bias weight at Hidden node  1 ::  -0.4323314754236865
# Bias weight at Hidden node  2 ::  0.197467030317643
#
#
# EPOCH- 11
# Error= 0.052301868399957485
# Weights at Output node:: -0.027118385460442523 0.24368620588242293
#
# Weights at Hidden node 1 :: 0.16724774033212048 0.4 -0.5327522596678795
#
# Weights at Hidden node 2 :: -0.29996053941902295 0.1 0.20003946058097707
#
# Bias weight at Output node::  0.9545975113132495
# Bias weight at Hidden node  1 ::  -0.43275225966787956
# Bias weight at Hidden node  2 ::  0.20003946058097707
#
#
# EPOCH- 12
# Error= 0.048324258284667326
# Weights at Output node:: -0.013618584417114978 0.2665197966906397
#
# Weights at Hidden node 1 :: 0.16699528219486942 0.4 -0.5330047178051306
#
# Weights at Hidden node 2 :: -0.29731757810010473 0.1 0.20268242189989527
#
# Bias weight at Output node::  0.9980893437694501
# Bias weight at Hidden node  1 ::  -0.4330047178051306
# Bias weight at Hidden node  2 ::  0.20268242189989527
#
#
# EPOCH- 13
# Error= 0.044812982610648124
# Weights at Output node:: -0.001106226225064651 0.28777401229999855
#
# Weights at Hidden node 1 :: 0.1668777460661303 0.4 -0.5331222539338697
#
# Weights at Hidden node 2 :: -0.29463810780847793 0.1 0.20536189219152207
#
# Bias weight at Output node::  1.0384210281190334
# Bias weight at Hidden node  1 ::  -0.43312225393386977
# Bias weight at Hidden node  2 ::  0.20536189219152207
#
#
# EPOCH- 14
# Error= 0.041701515602481525
# Weights at Output node:: 0.01053453883820007 0.30762768623791137
#
# Weights at Hidden node 1 :: 0.16686886278874324 0.4 -0.5331311372112567
#
# Weights at Hidden node 2 :: -0.29194704629821633 0.1 0.20805295370178367
#
# Bias weight at Output node::  1.0759523921612668
# Bias weight at Hidden node  1 ::  -0.4331311372112568
# Bias weight at Hidden node  2 ::  0.20805295370178367
#
#
# EPOCH- 15
# Error= 0.03893329068113857
# Weights at Output node:: 0.021402368257293743 0.32623390243641365
#
# Weights at Hidden node 1 :: 0.1669478414341485 0.4 -0.5330521585658514
#
# Weights at Hidden node 2 :: -0.2892625895248915 0.1 0.21073741047510855
#
# Bias weight at Output node::  1.1109923537742916
# Bias weight at Hidden node  1 ::  -0.43305215856585155
# Bias weight at Hidden node  2 ::  0.21073741047510855
#
#
# EPOCH- 16
# Error= 0.03646048478876237
# Weights at Output node:: 0.03158160282155919 0.3437241608772844
#
# Weights at Hidden node 1 :: 0.16709811976957453 0.4 -0.5329018802304254
#
# Weights at Hidden node 2 :: -0.28659795559326723 0.1 0.2134020444067328
#
# Bias weight at Output node::  1.1438067900841777
# Bias weight at Hidden node  1 ::  -0.43290188023042553
# Bias weight at Hidden node  2 ::  0.2134020444067328
#
#
# EPOCH- 17
# Error= 0.03424275577523772
# Weights at Output node:: 0.04114465313097335 0.3602118698495798
#
# Weights at Hidden node 1 :: 0.167306419775867 0.4 -0.5326935802241329
#
# Weights at Hidden node 2 :: -0.2839626637449504 0.1 0.21603733625504964
#
# Bias weight at Output node::  1.1746252702818918
# Bias weight at Hidden node  1 ::  -0.43269358022413307
# Bias weight at Hidden node  2 ::  0.21603733625504964
#
#
# EPOCH- 18
# Error= 0.03224606992432726
# Weights at Output node:: 0.05015396628581634 0.3757952479228079
#
# Weights at Hidden node 1 :: 0.16756203077150797 0.4 -0.532437969228492
#
# Weights at Hidden node 2 :: -0.281363475671683 0.1 0.218636524328317
#
# Bias weight at Output node::  1.2036467332137863
# Bias weight at Hidden node  1 ::  -0.4324379692284921
# Bias weight at Hidden node  2 ::  0.218636524328317
#
#
# EPOCH- 19
# Error= 0.03044167145603746
# Weights at Output node:: 0.058663641893788906 0.3905597254653987
#
# Weights at Hidden node 1 :: 0.1678562623760041 0.4 -0.5321437376239958
#
# Weights at Hidden node 2 :: -0.2788050913793235 0.1 0.22119490862067653
#
# Bias weight at Output node::  1.23104423752422
# Bias weight at Hidden node  1 ::  -0.432143737623996
# Bias weight at Hidden node  2 ::  0.22119490862067653
#
#
# EPOCH- 20
# Error= 0.0288052037200092
# Weights at Output node:: 0.06672075956206606 0.4045799297152535
#
# Weights at Hidden node 1 :: 0.16818202454941997 0.4 -0.53181797545058
#
# Weights at Hidden node 2 :: -0.2762906661034029 0.1 0.22370933389659717
#
# Bias weight at Output node::  1.2569689208722283
# Bias weight at Hidden node  1 ::  -0.43181797545058015
# Bias weight at Hidden node  2 ::  0.22370933389659717
#
#
# EPOCH- 21
# Error= 0.02731597255083704
# Weights at Output node:: 0.07436647094986626 0.41792132687599187
#
# Weights at Hidden node 1 :: 0.16853350312345008 0.4 -0.5314664968765498
#
# Weights at Hidden node 2 :: -0.27382219619996157 0.1 0.22617780380003852
#
# Bias weight at Output node::  1.2815532961679816
# Bias weight at Hidden node  1 ::  -0.43146649687655003
# Bias weight at Hidden node  2 ::  0.22617780380003852
#
#
# EPOCH- 22
# Error= 0.025956334790471505
# Weights at Output node:: 0.08163690042591454 0.4306415832440175
#
# Weights at Hidden node 1 :: 0.1689059074718527 0.4 -0.5310940925281472
#
# Weights at Hidden node 2 :: -0.27140080861838345 0.1 0.22859919138161666
#
# Bias weight at Output node::  1.304913997479406
# Bias weight at Hidden node  1 ::  -0.4310940925281474
# Bias weight at Hidden node  2 ::  0.22859919138161666
#
#
# EPOCH- 23
# Error= 0.0247111933301084
# Weights at Output node:: 0.08856389029793114 0.4427916966455745
#
# Weights at Hidden node 1 :: 0.1692952730008834 0.4 -0.5307047269991165
#
# Weights at Hidden node 2 :: -0.26902697903876627 0.1 0.23097302096123382
#
# Bias weight at Output node::  1.3271540714765035
# Bias weight at Hidden node  1 ::  -0.43070472699911666
# Bias weight at Hidden node  2 ::  0.23097302096123382
#
#
# EPOCH- 24
# Error= 0.023567581042076464
# Weights at Output node:: 0.09517561972437417 0.4544169401068654
#
# Weights at Hidden node 1 :: 0.16969830555758156 0.4 -0.5303016944424184
#
# Weights at Hidden node 2 :: -0.2667006969389365 0.1 0.23329930306106356
#
# Bias weight at Output node::  1.3483648944143725
# Bias weight at Hidden node  1 ::  -0.4303016944424185
# Bias weight at Hidden node  2 ::  0.23329930306106356
#
#
# EPOCH- 25
# Error= 0.022514318047448165
# Weights at Output node:: 0.10149712076305922 0.4655576518178759
#
# Weights at Hidden node 1 :: 0.17011225809375408 0.4 -0.5298877419062459
#
# Weights at Hidden node 2 :: -0.2644215909622834 0.1 0.23557840903771668
#
# Bias weight at Output node::  1.368627780657076
# Bias weight at Hidden node  1 ::  -0.429887741906246
# Bias weight at Hidden node  2 ::  0.23557840903771668
#
#
# EPOCH- 26
# Error= 0.021541729099804837
# Weights at Output node:: 0.10755071042311806 0.47624989898279146
#
# Weights at Hidden node 1 :: 0.17053483230819244 0.4 -0.5294651676918075
#
# Weights at Hidden node 2 :: -0.2621890244298794 0.1 0.2378109755701207
#
# Bias weight at Output node::  1.3880153368469004
# Bias weight at Hidden node  1 ::  -0.42946516769180765
# Bias weight at Hidden node  2 ::  0.2378109755701207
#
#
# EPOCH- 27
# Error= 0.020641410091068294
# Weights at Output node:: 0.11335635389953377 0.4865260378949852
#
# Weights at Hidden node 1 :: 0.17096409975276508 0.4 -0.5290359002472349
#
# Weights at Hidden node 2 :: -0.2600021682848979 0.1 0.2399978317151022
#
# Bias weight at Output node::  1.4065926059288618
# Bias weight at Hidden node  1 ::  -0.429035900247235
# Bias weight at Hidden node  2 ::  0.2399978317151022
#
#
# EPOCH- 28
# Error= 0.019806034653213817
# Weights at Output node:: 0.11893197122112362 0.4964151883348345
#
# Weights at Hidden node 1 :: 0.17139843819834633 0.4 -0.5286015618016536
#
# Weights at Hidden node 2 :: -0.25786005689615676 0.1 0.24213994310384332
#
# Bias weight at Output node::  1.4244180371167543
# Bias weight at Hidden node  1 ::  -0.4286015618016537
# Bias weight at Hidden node  2 ::  0.24213994310384332
#
#
# EPOCH- 29
# Error= 0.0190291935008765
# Weights at Output node:: 0.12429369719033866 0.5059436369800621
#
# Weights at Hidden node 1 :: 0.17183648003581745 0.4 -0.5281635199641825
#
# Weights at Hidden node 2 :: -0.25576163078440745 0.1 0.24423836921559264
#
# Bias weight at Output node::  1.4415443112675432
# Bias weight at Hidden node  1 ::  -0.4281635199641826
# Bias weight at Hidden node  2 ::  0.24423836921559264
#
#
# EPOCH- 30
# Error= 0.018305260546040137
# Weights at Output node:: 0.12945610261662643 0.5151351817813982
#
# Weights at Hidden node 1 :: 0.17227707022350996 0.4 -0.52772292977649
#
# Weights at Hidden node 2 :: -0.25370576933076927 0.1 0.2462942306692308
#
# Bias weight at Output node::  1.4580190457589794
# Bias weight at Hidden node  1 ::  -0.4277229297764901
# Bias weight at Hidden node  2 ::  0.2462942306692308
#
#
# EPOCH- 31
# Error= 0.017629280949562606
# Weights at Output node:: 0.13443238334648924 0.5240114270581265
#
# Weights at Hidden node 1 :: 0.1727192318491053 0.4 -0.5272807681508948
#
# Weights at Hidden node 2 :: -0.25169131578268505 0.1 0.24830868421731506
#
# Bias weight at Output node::  1.4738853986135858
# Bias weight at Hidden node  1 ::  -0.4272807681508948
# Bias weight at Hidden node  2 ::  0.24830868421731506
#
#
# EPOCH- 32
# Error= 0.01699687719342142
# Weights at Output node:: 0.13923452239426534 0.532592037300083
#
# Weights at Hidden node 1 :: 0.17316213779742107 0.4 -0.526837862202579
#
# Weights at Hidden node 2 :: -0.24971709631841 0.1 0.2502829036815901
#
# Bias weight at Output node::  1.489182588087665
# Bias weight at Hidden node  1 ::  -0.42683786220257897
# Bias weight at Hidden node  2 ::  0.2502829036815901
#
#
# EPOCH- 33
# Error= 0.016404169999200968
# Weights at Output node:: 0.14387342951571855 0.5408949562377322
#
# Weights at Hidden node 1 :: 0.1736050873394837 0.4 -0.5263949126605163
#
# Weights at Hidden node 2 :: -0.24778193451571123 0.1 0.2522180654842889
#
# Bias weight at Output node::  1.5039463410869458
# Bias weight at Hidden node  1 ::  -0.4263949126605163
# Bias weight at Hidden node  2 ::  0.2522180654842889
#
#
# EPOCH- 34
# Error= 0.015847711515303942
# Weights at Output node:: 0.14835906179251052 0.5489365965904769
#
# Weights at Hidden node 1 :: 0.17404748670759848 0.4 -0.5259525132924016
#
# Weights at Hidden node 2 :: -0.2458846622576181 0.1 0.254115337742382
#
# Bias weight at Output node::  1.5182092814507193
# Bias weight at Hidden node  1 ::  -0.4259525132924016
# Bias weight at Hidden node  2 ::  0.254115337742382
#
#
# EPOCH- 35
# Error= 0.015324428675510027
# Weights at Output node:: 0.15270052817077978 0.5567320049701188
#
# Weights at Hidden node 1 :: 0.17448883291407233 0.4 -0.5255111670859277
#
# Weights at Hidden node 2 :: -0.24402412787121416 0.1 0.2559758721287859
#
# Bias weight at Output node::  1.5320012672586782
# Bias weight at Hidden node  1 ::  -0.42551116708592773
# Bias weight at Hidden node  2 ::  0.2559758721287859
#
#
# EPOCH- 36
# Error= 0.014831575017837405
# Weights at Output node:: 0.15690618039086143 0.5642950056576062
#
# Weights at Hidden node 1 :: 0.17492870022138685 0.4 -0.5250712997786132
#
# Weights at Hidden node 2 :: -0.24219920211525983 0.1 0.25780079788474025
#
# Bias weight at Output node::  1.545349684774732
# Bias weight at Hidden node  1 ::  -0.4250712997786132
# Bias weight at Hidden node  2 ::  0.25780079788474025
#
#
# EPOCH- 37
# Error= 0.014366689563903462
# Weights at Output node:: 0.1609836923336459 0.5716383263521843
#
# Weights at Hidden node 1 :: 0.17536672878907894 0.4 -0.5246332712109212
#
# Weights at Hidden node 2 :: -0.2404087824946831 0.1 0.259591217505317
#
# Bias weight at Output node::  1.558279705382245
# Bias weight at Hidden node  1 ::  -0.4246332712109211
# Bias weight at Hidden node  2 ::  0.259591217505317
#
#
# EPOCH- 38
# Error= 0.013927561610177778
# Weights at Output node:: 0.16494012947327472 0.5787737084853433
#
# Weights at Hidden node 1 :: 0.17580261511495535 0.4 -0.5241973848850447
#
# Weights at Hidden node 2 :: -0.2386517962742073 0.1 0.26134820372579276
#
# Bias weight at Output node::  1.570814510831405
# Bias weight at Hidden node  1 ::  -0.4241973848850447
# Bias weight at Hidden node  2 ::  0.26134820372579276
#
#
# EPOCH- 39
# Error= 0.013512200485718717
# Weights at Output node:: 0.1687820098508653 0.585712004275707
#
# Weights at Hidden node 1 :: 0.1762361039612681 0.4 -0.523763896038732
#
# Weights at Hidden node 2 :: -0.23692720248182733 0.1 0.26307279751817275
#
# Bias weight at Output node::  1.5829754912685519
# Bias weight at Hidden node  1 ::  -0.423763896038732
# Bias weight at Hidden node  2 ::  0.26307279751817275
#
#
# EPOCH- 40
# Error= 0.013118809495772772
# Weights at Output node:: 0.17251535775791862 0.5924632623578878
#
# Weights at Hidden node 1 :: 0.17666698151445112 0.4 -0.5233330184855489
#
# Weights at Hidden node 2 :: -0.2352339931297077 0.1 0.2647660068702924
#
# Bias weight at Output node::  1.5947824198147473
# Bias weight at Hidden node  1 ::  -0.423333018485549
# Bias weight at Hidden node  2 ::  0.2647660068702924
#
#
# EPOCH- 41
# Error= 0.012745763404622844
# Weights at Output node:: 0.17614575113160344 0.599036803534512
#
# Weights at Hidden node 1 :: 0.1770950695732733 0.4 -0.5229049304267267
#
# Weights at Hidden node 2 :: -0.23357119383101543 0.1 0.2664288061689847
#
# Bias weight at Output node::  1.606253606878908
# Bias weight at Hidden node  1 ::  -0.42290493042672683
# Bias weight at Hidden node  2 ::  0.2664288061689847
#
#
# EPOCH- 42
# Error= 0.012391588920366054
# Weights at Output node:: 0.17967836350975122 0.6054412879650524
#
# Weights at Hidden node 1 :: 0.17752022059733447 0.4 -0.5224797794026655
#
# Weights at Hidden node 2 :: -0.23193786395294483 0.1 0.26806213604705525
#
# Bias weight at Output node::  1.6174060369072374
# Bias weight at Hidden node  1 ::  -0.4224797794026657
# Bias weight at Hidden node  2 ::  0.26806213604705525
#
#
# EPOCH- 43
# Error= 0.012054947733704574
# Weights at Output node:: 0.1831180012651652 0.6116847749089107
#
# Weights at Hidden node 1 :: 0.17794231347767112 0.4 -0.5220576865223289
#
# Weights at Hidden node 2 :: -0.23033309641626518 0.1 0.2696669035837349
#
# Bias weight at Output node::  1.6282554898675714
# Bias weight at Hidden node  1 ::  -0.42205768652232906
# Bias weight at Hidden node  2 ::  0.2696669035837349
#
#
# EPOCH- 44
# Error= 0.011734621736190465
# Weights at Output node:: 0.18646913673195634 0.61777477597627
#
# Weights at Hidden node 1 :: 0.17836124991535954 0.4 -0.5216387500846404
#
# Weights at Hidden node 2 :: -0.2287560172282429 0.1 0.2712439827717572
#
# Bias weight at Output node::  1.6388166494301428
# Bias weight at Hidden node  1 ::  -0.42163875008464063
# Bias weight at Hidden node  2 ::  0.2712439827717572
#
#
# EPOCH- 45
# Error= 0.011429500103738709
# Weights at Output node:: 0.18973593774722108 0.6237183027028076
#
# Weights at Hidden node 1 :: 0.17877695131357943 0.4 -0.5212230486864206
#
# Weights at Hidden node 2 :: -0.22720578481731768 0.1 0.27279421518268243
#
# Bias weight at Output node::  1.6491031995235077
# Bias weight at Hidden node  1 ::  -0.42122304868642074
# Bias weight at Hidden node  2 ::  0.27279421518268243
#
#
# EPOCH- 46
# Error= 0.011138567981066317
# Weights at Output node:: 0.19292229405636177 0.6295219091487996
#
# Weights at Hidden node 1 :: 0.17918935610455103 0.4 -0.520810643895449
#
# Weights at Hidden node 2 :: -0.22568158922334505 0.1 0.2743184107766551
#
# Bias weight at Output node::  1.6591279107064674
# Bias weight at Hidden node  1 ::  -0.42081064389544914
# Bias weight at Hidden node  2 ::  0.2743184107766551
#
#
# EPOCH- 47
# Error= 0.010860896543986111
# Weights at Output node:: 0.1960318409672071 0.6351917301256553
#
# Weights at Hidden node 1 :: 0.17959841744580188 0.4 -0.5204015825541981
#
# Weights at Hidden node 2 :: -0.22418265118570485 0.1 0.2758173488142953
#
# Bias weight at Output node::  1.668902717596055
# Bias weight at Hidden node  1 ::  -0.4204015825541983
# Bias weight at Hidden node  2 ::  0.2758173488142953
#
#
# EPOCH- 48
# Error= 0.010595634250765118
# Weights at Output node:: 0.19906798058477448 0.6407335155704378
#
# Weights at Hidden node 1 :: 0.18000410123092533 0.4 -0.5199958987690746
#
# Weights at Hidden node 2 :: -0.2227082211624599 0.1 0.2772917788375403
#
# Bias weight at Output node::  1.6784387884217435
# Bias weight at Hidden node  1 ::  -0.41999589876907484
# Bias weight at Hidden node  2 ::  0.2772917788375403
#
#
# EPOCH- 49
# Error= 0.010341999122313893
# Weights at Output node:: 0.20203390091336124 0.6461526615189229
#
# Weights at Hidden node 1 :: 0.18040638436881032 0.4 -0.5195936156311896
#
# Weights at Hidden node 2 :: -0.22125757830652026 0.1 0.27874242169347996
#
# Bias weight at Output node::  1.687746587631826
# Bias weight at Hidden node  1 ::  -0.41959361563118985
# Bias weight at Hidden node  2 ::  0.27874242169347996
#
#
# EPOCH- 50
# Error= 0.010099271914831353
# Weights at Output node:: 0.20493259307429862 0.6514542380681821
#
# Weights at Hidden node 1 :: 0.18080525329260858 0.4 -0.5191947467073913
#
# Weights at Hidden node 2 :: -0.21983002941902957 0.1 0.28016997058097065
#
# Bias weight at Output node::  1.6968359323551743
# Bias weight at Hidden node  1 ::  -0.4191947467073916
# Bias weight at Hidden node  2 ::  0.28016997058097065
#
#
# EPOCH- 51
# Error= 0.009866790068522225
# Weights at Output node:: 0.20776686685503218 0.6566430146688289
#
# Weights at Hidden node 1 :: 0.18120070266574698 0.4 -0.5187992973342529
#
# Weights at Hidden node 2 :: -0.21842490789562916 0.1 0.2815750921043711
#
# Bias weight at Output node::  1.7057160434168444
# Bias weight at Hidden node  1 ::  -0.4187992973342532
# Bias weight at Hidden node  2 ::  0.2815750921043711
#
#
# EPOCH- 52
# Error= 0.009643942332801437
# Weights at Output node:: 0.210539364777286 0.6617234830435654
#
# Weights at Hidden node 1 :: 0.1815927342573171 0.4 -0.5184072657426828
#
# Weights at Hidden node 2 :: -0.21704157267763027 0.1 0.28295842732237
#
# Bias weight at Output node::  1.7143955915163656
# Bias weight at Hidden node  1 ::  -0.4184072657426831
# Bias weight at Hidden node  2 ::  0.28295842732237
#
#
# EPOCH- 53
# Error= 0.00943016398255445
# Weights at Output node:: 0.21325257484816815 0.6666998779913367
#
# Weights at Hidden node 1 :: 0.1819813559633652 0.4 -0.5180186440366347
#
# Weights at Hidden node 2 :: -0.21567940721724266 0.1 0.2843205927827576
#
# Bias weight at Output node::  1.7228827391006645
# Bias weight at Hidden node  1 ::  -0.418018644036635
# Bias weight at Hidden node  2 ::  0.2843205927827576
#
#
# EPOCH- 54
# Error= 0.009224932551980458
# Weights at Output node:: 0.2159088421375505 0.6715761963042899
#
# Weights at Hidden node 1 :: 0.1823665809541126 0.4 -0.5176334190458872
#
# Weights at Hidden node 2 :: -0.21433781846371672 0.1 0.28566218153628353
#
# Bias weight at Output node::  1.7311851783974468
# Bias weight at Hidden node  1 ::  -0.41763341904588763
# Bias weight at Hidden node  2 ::  0.28566218153628353
#
#
# EPOCH- 55
# Error= 0.00902776402267614
# Weights at Output node:: 0.21851037930738776 0.6763562139970465
#
# Weights at Hidden node 1 :: 0.1827484269300779 0.4 -0.5172515730699219
#
# Weights at Hidden node 2 :: -0.2130162358754392 0.1 0.28698376412456106
#
# Bias weight at Output node::  1.7393101660178554
# Bias weight at Hidden node  1 ::  -0.41725157306992233
# Bias weight at Hidden node  2 ::  0.28698376412456106
#
#
# EPOCH- 56
# Error= 0.008838209411220458
# Weights at Output node:: 0.2210592762033925 0.6810435020238591
#
# Weights at Hidden node 1 :: 0.18312691547254778 0.4 -0.516873084527452
#
# Weights at Hidden node 2 :: -0.21171411046158067 0.1 0.2882858895384196
#
# Bias weight at Output node::  1.7472645544879537
# Bias weight at Hidden node  1 ::  -0.4168730845274524
# Bias weight at Hidden node  2 ::  0.2882858895384196
#
#
# EPOCH- 57
# Error= 0.008655851708847579
# Weights at Output node:: 0.22355750860629156 0.6856414406384856
#
# Weights at Hidden node 1 :: 0.18350207147593 0.4 -0.5164979285240697
#
# Weights at Hidden node 2 :: -0.2104309138557549 0.1 0.28956908614424537
#
# Bias weight at Output node::  1.7550548210259165
# Bias weight at Hidden node  1 ::  -0.4164979285240702
# Bias weight at Hidden node  2 ::  0.28956908614424537
#
#
# EPOCH- 58
# Error= 0.008480303132045949
# Weights at Output node:: 0.2260069462284519 0.6901532325336005
#
# Weights at Hidden node 1 :: 0.18387392265128757 0.4 -0.5161260773487122
#
# Weights at Hidden node 2 :: -0.20916613742325224 0.1 0.29083386257674804
#
# Bias weight at Output node::  1.7626870938447579
# Bias weight at Hidden node  1 ::  -0.4161260773487126
# Bias weight at Hidden node  2 ::  0.29083386257674804
#
#
# EPOCH- 59
# Error= 0.008311202648273348
# Weights at Output node:: 0.22840936003172363 0.6945819148808865
#
# Weights at Hidden node 1 :: 0.18424249909184923 0.4 -0.5157575009081505
#
# Weights at Hidden node 2 :: -0.20791929140270582 0.1 0.29208070859729446
#
# Bias weight at Output node::  1.7701671762282039
# Bias weight at Hidden node  1 ::  -0.41575750090815095
# Bias weight at Hidden node  2 ::  0.29208070859729446
#
#
# EPOCH- 60
# Error= 0.008148213745564029
# Weights at Output node:: 0.2307664289336904 0.6989303703792761
#
# Weights at Hidden node 1 :: 0.18460783289256225 0.4 -0.5153921671074375
#
# Weights at Hidden node 2 :: -0.20668990408250054 0.1 0.29331009591749974
#
# Bias weight at Output node::  1.7775005685992116
# Bias weight at Hidden node  1 ::  -0.4153921671074379
# Bias weight at Hidden node  2 ::  0.29331009591749974
#
#
# EPOCH- 61
# Error= 0.007991022418748047
# Weights at Output node:: 0.23307974596196107 0.703201337406857
#
# Weights at Hidden node 1 :: 0.18496995781683676 0.4 -0.515030042183163
#
# Weights at Hidden node 2 :: -0.20547752101181055 0.1 0.29452247898818973
#
# Bias weight at Output node::  1.7846924887760849
# Bias weight at Hidden node  1 ::  -0.4150300421831634
# Bias weight at Hidden node  2 ::  0.29452247898818973
#
#
# EPOCH- 62
# Error= 0.007839335348401144
# Weights at Output node:: 0.235350823909527 0.7073974193614871
#
# Weights at Hidden node 1 :: 0.1853289090045541 0.4 -0.5146710909954456
#
# Weights at Hidden node 2 :: -0.20428170424582645 0.1 0.29571829575417385
#
# Bias weight at Output node::  1.791747890589646
# Bias weight at Hidden node  1 ::  -0.4146710909954461
# Bias weight at Hidden node  2 ::  0.29571829575417385
#
#
# EPOCH- 63
# Error= 0.007692878251575132
# Weights at Output node:: 0.23758110053841697 0.7115210932659767
#
# Weights at Hidden node 1 :: 0.1856847227162022 0.4 -0.5143152772837976
#
# Weights at Hidden node 2 :: -0.20310203162448823 0.1 0.2968979683755121
#
# Bias weight at Output node::  1.7986714810160636
# Bias weight at Hidden node  1 ::  -0.41431527728379797
# Bias weight at Hidden node  2 ::  0.2968979683755121
#
#
# EPOCH- 64
# Error= 0.007551394385897617
# Weights at Output node:: 0.23977194337379534 0.7155747177056121
#
# Weights at Hidden node 1 :: 0.1860374361086786 0.4 -0.5139625638913211
#
# Weights at Hidden node 2 :: -0.20193809608385854 0.1 0.2980619039161418
#
# Bias weight at Output node::  1.8054677359633715
# Bias weight at Hidden node  1 ::  -0.4139625638913216
# Bias weight at Hidden node  2 ::  0.2980619039161418
#
#
# EPOCH- 65
# Error= 0.007414643190829209
# Weights at Output node:: 0.24192465412617367 0.7195605401586811
#
# Weights at Hidden node 1 :: 0.1863870870388827 0.4 -0.513612912961117
#
# Weights at Hidden node 2 :: -0.2007895049991408 0.1 0.2992104950008595
#
# Bias weight at Output node::  1.8121409148351177
# Bias weight at Hidden node  1 ::  -0.41361291296111746
# Bias weight at Hidden node  2 ::  0.2992104950008595
#
#
# EPOCH- 66
# Error= 0.007282399051777991
# Weights at Output node:: 0.24404047277546145 0.7234807037743731
#
# Weights at Hidden node 1 :: 0.18673371389172014 0.4 -0.5132662861082796
#
# Weights at Hidden node 2 :: -0.199655879558256 0.1 0.3003441204417443
#
# Bias weight at Output node::  1.818695073981718
# Bias weight at Hidden node  1 ::  -0.41326628610828003
# Bias weight at Hidden node  2 ::  0.3003441204417443
#
#
# EPOCH- 67
# Error= 0.00715445017443418
# Weights at Output node:: 0.24612058134709802 0.7273372536468748
#
# Weights at Hidden node 1 :: 0.18707735542957263 0.4 -0.5129226445704271
#
# Weights at Hidden node 2 :: -0.19853685416483394 0.1 0.30146314583516637
#
# Bias weight at Output node::  1.8251340791387087
# Bias weight at Hidden node  1 ::  -0.41292264457042754
# Bias weight at Hidden node  2 ::  0.30146314583516637
#
#
# EPOCH- 68
# Error= 0.007030597558139371
# Weights at Output node:: 0.2481661074074268 0.7311321426295592
#
# Weights at Hidden node 1 :: 0.1874180506606603 0.4 -0.5125819493393394
#
# Weights at Hidden node 2 :: -0.19743207586944225 0.1 0.30256792413055805
#
# Bias weight at Output node::  1.8314616169410343
# Bias weight at Hidden node  1 ::  -0.41258194933933984
# Bias weight at Hidden node  2 ::  0.30256792413055805
#
#
# EPOCH- 69
# Error= 0.006910654058371157
# Weights at Output node:: 0.2501781273027421 0.7348672367288012
#
# Weights at Hidden node 1 :: 0.1877558387240448 0.4 -0.512244161275955
#
# Weights at Hidden node 2 :: -0.19634120382786263 0.1 0.30365879617213765
#
# Bias weight at Output node::  1.8376812055935683
# Bias weight at Hidden node  1 ::  -0.41224416127595537
# Bias weight at Hidden node  2 ::  0.30365879617213765
#
#
# EPOCH- 70
# Error= 0.006794443529535035
# Weights at Output node:: 0.252157669164015 0.7385443201130742
#
# Weights at Hidden node 1 :: 0.18809075878930145 0.4 -0.5119092412106983
#
# Weights at Hidden node 2 :: -0.1952639087852264 0.1 0.3047360912147739
#
# Bias weight at Output node::  1.8437962047701497
# Bias weight at Hidden node  1 ::  -0.4119092412106987
# Bias weight at Hidden node  2 ::  0.3047360912147739
#
#
# EPOCH- 71
# Error= 0.006681800040226466
# Weights at Output node:: 0.25410571569715107 0.7421650997695267
#
# Weights at Hidden node 1 :: 0.18842284996913117 0.4 -0.5115771500308686
#
# Weights at Hidden node 2 :: -0.19419987258483543 0.1 0.3058001274151649
#
# Bias weight at Output node::  1.8498098248063535
# Bias weight at Hidden node  1 ::  -0.41157715003086903
# Bias weight at Hidden node  2 ::  0.3058001274151649
#
#
# EPOCH- 72
# Error= 0.006572567153982731
# Weights at Output node:: 0.25602320677671236 0.7457312098371586
#
# Weights at Hidden node 1 :: 0.188752151243393 0.4 -0.5112478487566067
#
# Weights at Hidden node 2 :: -0.19314878770051747 0.1 0.30685121229948287
#
# Bias weight at Output node::  1.855725135244938
# Bias weight at Hidden node  1 ::  -0.4112478487566072
# Bias weight at Hidden node  2 ::  0.30685121229948287
#
#
# EPOCH- 73
# Error= 0.006466597269293807
# Weights at Output node:: 0.2579110418593266 0.7492442156429717
#
# Weights at Hidden node 1 :: 0.1890787013932227 0.4 -0.510921298606777
#
# Weights at Hidden node 2 :: -0.19211035679139463 0.1 0.30788964320860573
#
# Bias weight at Output node::  1.8615450727873024
# Bias weight at Hidden node  1 ::  -0.4109212986067775
# Bias weight at Hidden node  2 ::  0.30788964320860573
#
#
# EPOCH- 74
# Error= 0.00636375101330659
# Weights at Output node:: 0.2597700822314769 0.752705617465006
#
# Weights at Hidden node 1 :: 0.1894025389440613 0.4 -0.5105974610559384
#
# Weights at Hidden node 2 :: -0.19108429227797807 0.1 0.3089157077220223
#
# Bias weight at Output node::  1.8672724486992784
# Bias weight at Hidden node  1 ::  -0.41059746105593886
# Bias weight at Hidden node  2 ::  0.3089157077220223
#
#
# EPOCH- 75
# Error= 0.006263896684239516
# Weights at Output node:: 0.26160115310499843 0.756116854043974
#
# Weights at Hidden node 1 :: 0.18972370211655942 0.4 -0.5102762978834403
#
# Weights at Hidden node 2 :: -0.1900703159385404 0.1 0.30992968406146
#
# Bias weight at Output node::  1.872909955715094
# Bias weight at Hidden node  1 ::  -0.4102762978834407
# Bias weight at Hidden node  2 ::  0.30992968406146
#
#
# EPOCH- 76
# Error= 0.006166909738043839
# Weights at Output node:: 0.26340504557238464 0.7594793058632322
#
# Weights at Hidden node 1 :: 0.19004222878444282 0.4 -0.509957771215557
#
# Weights at Hidden node 2 :: -0.18906815852475664 0.1 0.3109318414752438
#
# Bias weight at Output node::  1.8784601744793337
# Bias weight at Hidden node  1 ::  -0.4099577712155573
# Bias weight at Hidden node  2 ::  0.3109318414752438
#
#
# EPOCH- 77
# Error= 0.006072672315304222
# Weights at Output node:: 0.26518251843290536 0.7627942982150528
#
# Weights at Hidden node 1 :: 0.1903581564385339 0.4 -0.5096418435614659
# Weights at Hidden node 2 :: -0.18807755939564674 0.1 0.31192244060435365
#
# Bias weight at Output node::  1.8839255795631074
# Bias weight at Hidden node  1 ::  -0.4096418435614662
# Bias weight at Hidden node  2 ::  0.31192244060435365
#
#
# EPOCH- 78
# Error= 0.005981072804778843
# Weights at Output node:: 0.2669342998995538 0.7660631040695686
#
# Weights at Hidden node 1 :: 0.19067152215621627 0.4 -0.5093284778437835
#
# Weights at Hidden node 2 :: -0.18709826616889416 0.1 0.31290173383110625
#
# Bias weight at Output node::  1.8893085450874083
# Bias weight at Hidden node  1 ::  -0.40932847784378384
# Bias weight at Hidden node  2 ::  0.31290173383110625
#
#
# EPOCH- 79
# Error= 0.005892005440338911
# Weights at Output node:: 0.26866108919595083 0.7692869467613239
#
# Weights at Hidden node 1 :: 0.19098236257571224 0.4 -0.5090176374242875
#
# Weights at Hidden node 2 :: -0.1861300343886568 0.1 0.3138699656113436
#
# Bias weight at Output node::  1.8946113499837134
# Bias weight at Hidden node  1 ::  -0.40901763742428787
# Bias weight at Hidden node  2 ::  0.3138699656113436
#
#
# EPOCH- 80
# Error= 0.005805369928388916
# Weights at Output node:: 0.27036355805153583 0.7724670025070757
#
# Weights at Hidden node 1 :: 0.19129071387461583 0.4 -0.5087092861253839
#
# Weights at Hidden node 2 :: -0.18517262720902877 0.1 0.31482737279097167
#
# Bias weight at Output node::  1.8998361829192634
# Bias weight at Hidden node  1 ::  -0.4087092861253843
# Bias weight at Hidden node  2 ::  0.31482737279097167
#
#
# EPOCH- 81
# Error= 0.005721071103134831
# Weights at Output node:: 0.27204235210265265 0.7756044027673134
#
# Weights at Hidden node 1 :: 0.19159661175218676 0.4 -0.508403388247813
#
# Weights at Hidden node 2 :: -0.18422581509235117 0.1 0.31577418490764925
#
# Bias weight at Output node::  1.9049851469120846
# Bias weight at Hidden node  1 ::  -0.40840338824781336
# Bias weight at Hidden node  2 ::  0.31577418490764925
#
#
# EPOCH- 82
# Error= 0.00563901860732168
# Weights at Output node:: 0.27369809220648766 0.7787002364629181
#
# Weights at Hidden node 1 :: 0.19190009141496803 0.4 -0.5080999085850317
#
# Weights at Hidden node 2 :: -0.18328937552161065 0.1 0.31671062447838977
#
# Bias weight at Output node::  1.910060263658674
# Bias weight at Hidden node  1 ::  -0.4080999085850321
# Bias weight at Hidden node  2 ::  0.31671062447838977
#
#
# EPOCH- 83
# Error= 0.005559126596290419
# Weights at Output node:: 0.2753313756742293 0.7817555520574201
#
# Weights at Hidden node 1 :: 0.19220118756533802 0.4 -0.5077988124346617
#
# Weights at Hidden node 2 :: -0.18236309272620216 0.1 0.3176369072737983
#
# Bias weight at Output node::  1.9150634775953355
# Bias weight at Hidden node  1 ::  -0.4077988124346621
# Bias weight at Hidden node  2 ::  0.3176369072737983
#
#
# EPOCH- 84
# Error= 0.005481313463407073
# Weights at Output node:: 0.2769427774292844 0.7847713595144503
#
# Weights at Hidden node 1 :: 0.19249993439265287 0.4 -0.507500065607347
#
# Weights at Hidden node 2 :: -0.18144675742036998 0.1 0.31855324257963047
#
# Bias weight at Output node::  1.9199966597124019
# Bias weight at Hidden node  1 ::  -0.40750006560734725
# Bias weight at Hidden node  2 ::  0.31855324257963047
#
#
# EPOCH- 85
# Error= 0.005405501585099284
# Weights at Output node:: 0.2785328510959065 0.7877486321391968
#
# Weights at Hidden node 1 :: 0.19279636556667232 0.4 -0.5072036344333275
#
# Weights at Hidden node 2 :: -0.18054016655367627 0.1 0.31945983344632417
#
# Bias weight at Output node::  1.9248616111389911
# Bias weight at Hidden node  1 ::  -0.4072036344333278
# Bias weight at Hidden node  2 ::  0.31945983344632417
#
#
# EPOCH- 86
# Error= 0.005331617083899477
# Weights at Output node:: 0.28010213002314976 0.7906883083119622
#
# Weights at Hidden node 1 :: 0.1930905142329975 0.4 -0.5069094857670023
#
# Weights at Hidden node 2 :: -0.17964312307288102 0.1 0.3203568769271194
#
# Bias weight at Output node::  1.9296600665145007
# Bias weight at Hidden node  1 ::  -0.4069094857670026
# Bias weight at Hidden node  2 ::  0.3203568769271194
#
#
# EPOCH- 87
# Error= 0.005259589608039878
# Weights at Output node:: 0.2816511282486691 0.7935912931212729
#
# Weights at Hidden node 1 :: 0.1933824130102784 0.4 -0.5066175869897215
#
# Weights at Hidden node 2 :: -0.1787554356946492 0.1 0.32124456430535125
#
# Bias weight at Output node::  1.9343936971617366
# Bias weight at Hidden node  1 ::  -0.40661758698972167
# Bias weight at Hidden node  2 ::  0.32124456430535125
#
#
# EPOCH- 88
# Error= 0.005189352126276561
# Weights at Output node:: 0.28318034140652115 0.7964584599033966
#
# Weights at Hidden node 1 :: 0.19367209398897597 0.4 -0.5063279060110238
#
# Weights at Hidden node 2 :: -0.17787691868853284 0.1 0.3221230813114676
#
# Bias weight at Output node::  1.9390641140753855
# Bias weight at Hidden node  1 ::  -0.4063279060110241
# Bias weight at Hidden node  2 ::  0.3221230813114676
#
#
# EPOCH- 89
# Error= 0.0051208407367388615
# Weights at Output node:: 0.2846902475827948 0.7992906516945937
#
# Weights at Hidden node 1 :: 0.1939595887314878 0.4 -0.506040411268512
#
# Weights at Hidden node 2 :: -0.17700739166970497 0.1 0.32299260833029547
#
# Bias weight at Output node::  1.9436728707384505
# Bias weight at Hidden node  1 ::  -0.40604041126851226
# Bias weight at Hidden node  2 ::  0.32299260833029547
#
#
# EPOCH- 90
# Error= 0.00505399448870665
# Weights at Output node:: 0.28618130812259923 0.8020886826019306
#
# Weights at Hidden node 1 :: 0.1942449282734667 0.4 -0.5057550717265331
#
# Weights at Hidden node 2 :: -0.17614667940095025 0.1 0.3238533205990502
#
# Bias weight at Output node::  1.9482214657782866
# Bias weight at Hidden node  1 ::  -0.40575507172653336
# Bias weight at Hidden node  2 ::  0.3238533205990502
#
#
# EPOCH- 91
# Error= 0.004988755216314714
# Weights at Output node:: 0.28765396839166335 0.804853339098043
#
# Weights at Hidden node 1 :: 0.19452814312618094 0.4 -0.5054718568738189
#
# Weights at Hidden node 2 :: -0.1752946116034445 0.1 0.32470538839655594
#
# Bias weight at Output node::  1.9527113454729699
# Bias weight at Hidden node  1 ::  -0.40547185687381915
# Bias weight at Hidden node  2 ::  0.32470538839655594
#
#
# EPOCH- 92
# Error= 0.004925067383270474
# Weights at Output node:: 0.2891086584955523 0.8075853812448232
#
# Weights at Hidden node 1 :: 0.19480926327978118 0.4 -0.5051907367202186
#
# Weights at Hidden node 2 :: -0.17445102277588012 0.1 0.3255489772241203
#
# Bias weight at Output node::  1.9571439061179132
# Bias weight at Hidden node  1 ::  -0.4051907367202189
# Bias weight at Hidden node  2 ::  0.3255489772241203
#
#
# EPOCH- 93
# Error= 0.004862877937749883
# Weights at Output node:: 0.29054579395927727 0.8102855438506339
#
# Weights at Hidden node 1 :: 0.195088318207354 0.4 -0.5049116817926458
#
# Weights at Hidden node 2 :: -0.17361575202151844 0.1 0.326384247978482
#
# Bias weight at Output node::  1.9615204962618882
# Bias weight at Hidden node  1 ::  -0.404911681792646
# Bias weight at Hidden node  2 ::  0.326384247978482
#
#
# EPOCH- 94
# Error= 0.00480213617670726
# Weights at Output node:: 0.29196577636986754 0.8129545375653101
#
# Weights at Hidden node 1 :: 0.19536533686965513 0.4 -0.5046346631303447
#
# Weights at Hidden node 2 :: -0.17278864288277315 0.1 0.32721135711722726
#
# Bias weight at Output node::  1.9658424188209247
# Bias weight at Hidden node  1 ::  -0.4046346631303449
# Bias weight at Hidden node  2 ::  0.32721135711722726
#
#
# EPOCH- 95
# Error= 0.004742793618899657
# Weights at Output node:: 0.2933689939842817 0.8155930499168939
#
# Weights at Hidden node 1 :: 0.19564034772042713 0.4 -0.5043596522795727
#
# Weights at Hidden node 2 :: -0.17196954318295002 0.1 0.3280304568170504
#
# Bias weight at Output node::  1.9701109330779343
# Bias weight at Hidden node  1 ::  -0.4043596522795729
# Bias weight at Hidden node  2 ::  0.3280304568170504
#
#
# EPOCH- 96
# Error= 0.004684803885984507
# Weights at Output node:: 0.29475582230486025 0.8182017462937616
#
# Weights at Hidden node 1 :: 0.1959133787122171 0.4 -0.5040866212877827
#
# Weights at Hidden node 2 :: -0.1711583048747884 0.1 0.328841695125212
#
# Bias weight at Output node::  1.9743272565753203
# Bias weight at Hidden node  1 ::  -0.4040866212877829
# Bias weight at Hidden node  2 ::  0.328841695125212
#
#
# EPOCH- 97
# Error= 0.004628122591102447
# Weights at Output node:: 0.2961266246243622 0.8207812708755404
#
# Weights at Hidden node 1 :: 0.1961844573026187 0.4 -0.5038155426973812
#
# Weights at Hidden node 2 :: -0.17035478389546949 0.1 0.3296452161045309
#
# Bias weight at Output node::  1.9784925669073126
# Bias weight at Hidden node  1 ::  -0.4038155426973813
# Bias weight at Hidden node  2 ::  0.3296452161045309
#
#
# EPOCH- 98
# Error= 0.0045727072344050575
# Weights at Output node:: 0.2974817525424785 0.8233322475159631
#
# Weights at Hidden node 1 :: 0.19645361046087176 0.4 -0.5035463895391281
#
# Weights at Hidden node 2 :: -0.16955884002777424 0.1 0.3304411599722261
#
# Bias weight at Output node::  1.9826080034182771
# Bias weight at Hidden node  1 ::  -0.4035463895391282
# Bias weight at Hidden node  2 ::  0.3304411599722261
#
#
# EPOCH- 99
# Error= 0.004518517105031788
# Weights at Output node:: 0.2988215464555835 0.8258552805805948
#
# Weights at Hidden node 1 :: 0.1967208646747598 0.4 -0.50327913532524
#
# Weights at Hidden node 2 :: -0.16877033676709075 0.1 0.33122966323290964
#
# Bias weight at Output node::  1.9866746688128059
# Bias weight at Hidden node  1 ::  -0.4032791353252402
# Bias weight at Hidden node  2 ::  0.33122966323290964
#
#
# EPOCH- 100
# Error= 0.004465513189079166
# Weights at Output node:: 0.30014633602135693 0.8283509557421527
#
# Weights at Hidden node 1 :: 0.19698624595775227 0.4 -0.5030137540422476
#
# Weights at Hidden node 2 :: -0.16798914119398736 0.1 0.332010858806013
#
# Bias weight at Output node::  1.990693630682977
# Bias weight at Hidden node  1 ::  -0.4030137540422477
# Bias weight at Hidden node  2 ::  0.332010858806013
#
#
# EPOCH- 101
# Error= 0.004413658083142802
# Weights at Output node:: 0.3014564405997977 0.8308198407359562
#
# Weights at Hidden node 1 :: 0.19724977985634484 0.4 -0.502750220143655
#
# Weights at Hidden node 2 :: -0.16721512385208295 0.1 0.3327848761479174
#
# Bias weight at Output node::  1.9946659229578054
# Bias weight at Hidden node  1 ::  -0.40275022014365514
# Bias weight at Hidden node  2 ::  0.3327848761479174
#
#
# EPOCH- 102
# Error= 0.004362915913044679
# Weights at Output node:: 0.30275216967204366 0.8332624860778675
#
# Weights at Hidden node 1 :: 0.19751149145755587 0.4 -0.502488508542444
#
# Weights at Hidden node 2 :: -0.1664481586309598 0.1 0.3335518413690406
#
# Bias weight at Output node::  1.9985925472795456
# Bias weight at Hidden node  1 ::  -0.4024885085424441
# Bias weight at Hidden node  2 ::  0.3335518413690406
#
#
# EPOCH- 103
# Error= 0.004313252257389836
# Weights at Output node:: 0.30403382323831396 0.8356794257469231
# Weights at Hidden node 1 :: 0.1977714053965418 0.4 -0.502228594603458
#
# Weights at Hidden node 2 :: -0.16568812265387844 0.1 0.33431187734612194
#
# Bias weight at Output node::  2.0024744743111964
# Bias weight at Hidden node  1 ::  -0.40222859460345817
# Bias weight at Hidden node  2 ::  0.33431187734612194
#
#
# EPOCH- 104
# Error= 0.004264634075622354
# Weights at Output node:: 0.305301692196202 0.8380711778347089
#
# Weights at Hidden node 1 :: 0.1980295458642994 0.4 -0.5019704541357004
#
# Weights at Hidden node 2 :: -0.1649348961700667 0.1 0.3350651038299337
#
# Bias weight at Output node::  2.0063126449792565
# Bias weight at Hidden node  1 ::  -0.40197045413570054
# Bias weight at Hidden node  2 ::  0.3350651038299337
#
#
# EPOCH- 105
# Error= 0.004217029640277567
# Weights at Output node:: 0.3065560587004632 0.8404382451633917
#
# Weights at Hidden node 1 :: 0.19828593661542504 0.4 -0.5017140633845748
#
# Weights at Hidden node 2 :: -0.1641883624513666 0.1 0.33581163754863386
#
# Bias weight at Output node::  2.0101079716555064
# Bias weight at Hidden node  1 ::  -0.4017140633845749
# Bias weight at Hidden node  2 ::  0.33581163754863386
#
#
# EPOCH- 106
# Error= 0.004170408473149563
# Weights at Output node:: 0.30779719650536536 0.842781115874198
#
# Weights at Hidden node 1 :: 0.19854060097590612 0.4 -0.5014593990240938
#
# Weights at Hidden node 2 :: -0.16344840769303487 0.1 0.3365515923069656
#
# Bias weight at Output node::  2.013861339281341
# Bias weight at Hidden node  1 ::  -0.40145939902409383
# Bias weight at Hidden node  2 ::  0.3365515923069656
#
#
# EPOCH- 107
# Error= 0.0041247412851139415
# Weights at Output node:: 0.30902537129059926 0.8451002639880074
#
# Weights at Hidden node 1 :: 0.19879356185092178 0.4 -0.5012064381490781
#
# Weights at Hidden node 2 :: -0.16271492091850343 0.1 0.337285079081497
#
# Bias weight at Output node::  2.0175736064379435
# Bias weight at Hidden node  1 ::  -0.4012064381490782
# Bias weight at Hidden node  2 ::  0.337285079081497
#
#
# EPOCH- 108
# Error= 0.00407999991936615
# Weights at Output node:: 0.31024084097168053 0.8473961499396258
#
# Weights at Hidden node 1 :: 0.19904484173263323 0.4 -0.5009551582673666
#
# Weights at Hidden node 2 :: -0.16198779388791548 0.1 0.33801220611208493
#
# Bias weight at Output node::  2.021245606365373
# Bias weight at Hidden node  1 ::  -0.4009551582673667
# Bias weight at Hidden node  2 ::  0.33801220611208493
#
#
# EPOCH- 109
# Error= 0.004036157297852453
# Weights at Output node:: 0.3114438559957143 0.8496692210871968
#
# Weights at Hidden node 1 :: 0.1992944627079462 0.4 -0.5007055372920536
#
# Weights at Hidden node 2 :: -0.16126692101026385 0.1 0.33873307898973654
#
# Bias weight at Output node::  2.0248781479334403
# Bias weight at Hidden node  1 ::  -0.40070553729205377
# Bias weight at Hidden node  2 ::  0.33873307898973654
#
#
# EPOCH- 110
# Error= 0.0039931873706878255
# Weights at Output node:: 0.3126346596233368 0.851919912198122
#
# Weights at Hidden node 1 :: 0.19954244646623034 0.4 -0.5004575535337694
#
# Weights at Hidden node 2 :: -0.16055219925896594 0.1 0.3394478007410344
#
# Bias weight at Output node::  2.0284720165670596
# Bias weight at Hidden node  1 ::  -0.40045755353376966
# Bias weight at Hidden node  2 ::  0.3394478007410344
#
#
# EPOCH- 111
# Error= 0.0039510650683689235
# Weights at Output node:: 0.3138134881975972 0.8541486459127688
#
# Weights at Hidden node 1 :: 0.19978881430698234 0.4 -0.5002111856930175
#
# Weights at Hidden node 2 :: -0.15984352809071886 0.1 0.3401564719092815
#
# Bias weight at Output node::  2.0320279751285915
# Bias weight at Hidden node  1 ::  -0.40021118569301767
# Bias weight at Hidden node  2 ::  0.3401564719092815
#
#
# EPOCH- 112
# Error= 0.003909766256605778
# Weights at Output node:: 0.31498057140049324 0.8563558331871689
#
# Weights at Hidden node 1 :: 0.20003358714742117 0.4 -0.49996641285257865
#
# Weights at Hidden node 2 :: -0.15914080936748612 0.1 0.34085919063251424
#
# Bias weight at Output node::  2.0355467647595367
# Bias weight at Hidden node  1 ::  -0.39996641285257883
# Bias weight at Hidden node  2 ::  0.34085919063251424
#
#
# EPOCH- 113
# Error= 0.003869267693606283
# Weights at Output node:: 0.3161361324978309 0.8585418737158317
#
# Weights at Hidden node 1 :: 0.2002767855300057 0.4 -0.4997232144699941
#
# Weights at Hidden node 2 :: -0.15844394728147498 0.1 0.3415560527185254
#
# Bias weight at Output node::  2.0390291056837824
# Bias weight at Hidden node  1 ::  -0.3997232144699943
# Bias weight at Hidden node  2 ::  0.3415560527185254
#
#
# EPOCH- 114
# Error= 0.003829546989661467
# Weights at Output node:: 0.3172803885730348 0.8607071563357312
#
# Weights at Hidden node 1 :: 0.2005184296298656 0.4 -0.49948157037013424
#
# Weights at Hidden node 2 :: -0.15775284828297034 0.1 0.3422471517170301
#
# Bias weight at Output node::  2.042475697974478
# Bias weight at Hidden node  1 ::  -0.39948157037013443
# Bias weight at Hidden node  2 ::  0.3422471517170301
#
#
# EPOCH- 115
# Error= 0.0037905825688886625
# Weights at Output node:: 0.31841355075049876 0.8628520594124568
#
# Weights at Hidden node 1 :: 0.200758539262139 0.4 -0.49924146073786085
#
# Weights at Hidden node 2 :: -0.1570674210108984 0.1 0.342932578989102
#
# Bias weight at Output node::  2.0458872222864777
# Bias weight at Hidden node  1 ::  -0.39924146073786104
# Bias weight at Hidden node  2 ::  0.342932578989102
#
#
# EPOCH- 116
# Error= 0.003752353633000352
# Weights at Output node:: 0.31953582440902917 0.8649769512094599
#
# Weights at Hidden node 1 :: 0.20099713388920976 0.4 -0.4990028661107901
#
# Weights at Hidden node 2 :: -0.15638757622599925 0.1 0.34361242377400114
#
# Bias weight at Output node::  2.049264340556178
# Bias weight at Hidden node  1 ::  -0.3990028661107903
# Bias weight at Hidden node  2 ::  0.34361242377400114
#
#
# EPOCH- 117
# Error= 0.0037148401269757026
# Weights at Output node:: 0.32064740938590025 0.8670821902412736
#
# Weights at Hidden node 1 :: 0.20123423262783996 0.4 -0.4987657673721599
#
# Weights at Hidden node 2 :: -0.15571322674649363 0.1 0.34428677325350676
#
# Bias weight at Output node::  2.052607696670456
# Bias weight at Hidden node  1 ::  -0.3987657673721601
# Bias weight at Hidden node  2 ::  0.34428677325350676
#
#
# EPOCH- 118
# Error= 0.003678022706519397
# ...
#
# Weights at Hidden node 1 :: 0.2330139007723035 0.4 -0.46698609922769657
#
# Weights at Hidden node 2 :: -0.07411061420040171 0.1 0.4258893857995986
#
# Bias weight at Output node::  2.420996279751777
# Bias weight at Hidden node  1 ::  -0.36698609922769676
# Bias weight at Hidden node  2 ::  0.4258893857995986
#
#
# EPOCH- 327
# Error= 0.001132911031324232
# Weights at Output node:: 0.4472275870856782 1.1098475808369312
#
# Weights at Hidden node 1 :: 0.23311811353331935 0.4 -0.4668818864666807
#
# Weights at Hidden node 2 :: -0.07386666624982634 0.1 0.426133333750174
#
# Bias weight at Output node::  2.4220158996799688
# Bias weight at Hidden node  1 ::  -0.3668818864666809
# Bias weight at Hidden node  2 ::  0.426133333750174
#
#
# EPOCH- 328
# Error= 0.0011289771082285953
# Weights at Output node:: 0.44758747833475115 1.1105439357887408
#
# Weights at Hidden node 1 :: 0.23322205781645497 0.4 -0.4667779421835451
#
# Weights at Hidden node 2 :: -0.0736234782137592 0.1 0.42637652178624114
#
# Bias weight at Output node::  2.4230319790773747
# Bias weight at Hidden node  1 ::  -0.3667779421835453
# Bias weight at Hidden node  2 ::  0.42637652178624114
#
#
# EPOCH- 329
# Error= 0.0011250690939025995
# Weights at Output node:: 0.44794619602946684 1.1112380395568506
#
# Weights at Hidden node 1 :: 0.23332573507196586 0.4 -0.46667426492803427
#
# Weights at Hidden node 2 :: -0.07338104552723841 0.1 0.42661895447276194
#
# Bias weight at Output node::  2.424044541261887
# Bias weight at Hidden node  1 ::  -0.36667426492803445
# Bias weight at Hidden node  2 ::  0.42661895447276194
#
#
# EPOCH- 330
# Error= 0.001121186738550695
# Weights at Output node:: 0.44830374767242004 1.1119299063326422
#
# Weights at Hidden node 1 :: 0.23342914673822796 0.4 -0.46657085326177217
#
# Weights at Hidden node 2 :: -0.0731393636658884 0.1 0.426860636334112
#
# Bias weight at Output node::  2.4250536093265826
# Bias weight at Hidden node  1 ::  -0.36657085326177236
# Bias weight at Hidden node  2 ::  0.426860636334112
#
#
# EPOCH- 331
# Error= 0.0011173297955399339
# Weights at Output node:: 0.4486601406952603 1.1126195501750107
#
# Weights at Hidden node 1 :: 0.2335322942418675 0.4 -0.4664677057581326
#
# Weights at Hidden node 2 :: -0.07289842814544259 0.1 0.42710157185455777
#
# Bias weight at Output node::  2.4260592061425688
# Bias weight at Hidden node  1 ::  -0.3664677057581328
# Bias weight at Hidden node  2 ::  0.42710157185455777
#
#
# EPOCH- 332
# Error= 0.0011134980213503114
# Weights at Output node:: 0.4490153824595772 1.1133069850119997
#
# Weights at Hidden node 1 :: 0.2336351789978892 0.4 -0.4663648210021109
#
# Weights at Hidden node 2 :: -0.07265823452127315 0.1 0.4273417654787272
#
# Bias weight at Output node::  2.427061354361784
# Bias weight at Hidden node  1 ::  -0.3663648210021111
# Bias weight at Hidden node  2 ::  0.4273417654787272
#
#
# EPOCH- 333
# Error= 0.0011096911755262315
# Weights at Output node:: 0.44936948025777207 1.113992224642411
#
# Weights at Hidden node 1 :: 0.2337378024098026 0.4 -0.4662621975901975
#
# Weights at Hidden node 2 :: -0.07241877838792751 0.1 0.42758122161207285
#
# Bias weight at Output node::  2.4280600764197575
# Bias weight at Hidden node  1 ::  -0.3662621975901977
# Bias weight at Hidden node  2 ::  0.42758122161207285
#
#
# EPOCH- 334
# Error= 0.0011059090206289187
# Weights at Output node:: 0.44972244131391625 1.1146752827373896
#
# Weights at Hidden node 1 :: 0.23384016586974685 0.4 -0.46615983413025325
#
# Weights at Hidden node 2 :: -0.07218005537867168 0.1 0.42781994462132866
#
# Bias weight at Output node::  2.4290553945383238
# Bias weight at Hidden node  1 ::  -0.36615983413025344
# Bias weight at Hidden node  2 ::  0.42781994462132866
#
#
# EPOCH- 335
# Error= 0.0011021513221895136
# Weights at Output node:: 0.450074272784596 1.1153561728419847
#
# Weights at Hidden node 1 :: 0.23394227075861354 0.4 -0.46605772924138655
#
# Weights at Hidden node 2 :: -0.07194206116504015 0.1 0.4280579388349602
#
# Bias weight at Output node::  2.430047330728294
# Bias weight at Hidden node  1 ::  -0.36605772924138674
# Bias weight at Hidden node  2 ::  0.4280579388349602
#
#
# EPOCH- 336
# Error= 0.0010984178486632165
# Weights at Output node:: 0.4504249817597444 1.116034908376687
#
# Weights at Hidden node 1 :: 0.23404411844616818 0.4 -0.4659558815538319
#
# Weights at Hidden node 2 :: -0.07170479145639225 0.1 0.4282952085436081
# Bias weight at Output node::  2.4310359067920913
# Bias weight at Hidden node  1 ::  -0.3659558815538321
# Bias weight at Hidden node  2 ::  0.4282952085436081
#
#
# EPOCH- 337
# Error= 0.0010947083713841999
# Weights at Output node:: 0.45077457526346093 1.1167115026389423
#
# Weights at Hidden node 1 :: 0.23414571029116987 0.4 -0.4658542897088302
#
# Weights at Hidden node 2 :: -0.07146824199947499 0.1 0.42853175800052534
#
# Bias weight at Output node::  2.432021144326337
# Bias weight at Hidden node  1 ::  -0.3658542897088304
# Bias weight at Hidden node  2 ::  0.42853175800052534
#
#
# EPOCH- 338
# Error= 0.0010910226645213011
# Weights at Output node:: 0.45112306025481813 1.117385968804643
#
# Weights at Hidden node 1 :: 0.23424704764148938 0.4 -0.4657529523585107
#
# Weights at Hidden node 2 :: -0.07123240857799214 0.1 0.4287675914220082
#
# Bias weight at Output node::  2.433003064724406
# Bias weight at Hidden node  1 ::  -0.3657529523585109
# Bias weight at Hidden node  2 ::  0.4287675914220082
#
#
# EPOCH- 339
# Error= 0.001087360505034658
# Weights at Output node:: 0.45147044362865624 1.1180583199295968
#
# Weights at Hidden node 1 :: 0.23434813183422562 0.4 -0.4656518681657745
#
# Weights at Hidden node 2 :: -0.07099728701217942 0.1 0.42900271298782094
#
# Bias weight at Output node::  2.433981689178937
# Bias weight at Hidden node  1 ::  -0.36565186816577466
# Bias weight at Hidden node  2 ::  0.42900271298782094
#
#
# EPOCH- 340
# Error= 0.0010837216726329803
# Weights at Output node:: 0.45181673221636565 1.1187285689509734
#
# Weights at Hidden node 1 :: 0.23444896419582079 0.4 -0.46555103580417934
#
# Weights at Hidden node 2 :: -0.07076287315838585 0.1 0.4292371268416145
#
# Bias weight at Output node::  2.4349570386843067
# Bias weight at Hidden node  1 ::  -0.3655510358041795
# Bias weight at Hidden node  2 ::  0.4292371268416145
#
#
# EPOCH- 341
# Error= 0.0010801059497317406
# Weights at Output node:: 0.4521619327866577 1.119396728688729
#
# Weights at Hidden node 1 :: 0.2345495460421736 0.4 -0.4654504539578265
#
# Weights at Hidden node 2 :: -0.07052916290866101 0.1 0.4294708370913394
#
# Bias weight at Output node::  2.4359291340390654
# Bias weight at Hidden node  1 ::  -0.3654504539578267
# Bias weight at Hidden node  2 ::  0.4294708370913394
#
#
# EPOCH- 342
# Error= 0.0010765131214119689
# Weights at Output node:: 0.4525060520463238 1.1200628118470108
#
# Weights at Hidden node 1 :: 0.2346498786787513 0.4 -0.4653501213212488
#
# Weights at Hidden node 2 :: -0.07029615219034817 0.1 0.4297038478096522
#
# Bias weight at Output node::  2.4368979958483363
# Bias weight at Hidden node  1 ::  -0.365350121321249
# Bias weight at Hidden node  2 ::  0.4297038478096522
#
#
# EPOCH- 343
# Error= 0.0010729429753799625
# Weights at Output node:: 0.452849096640983 1.1207268310155398
#
# Weights at Hidden node 1 :: 0.2347499634007002 0.4 -0.4652500365992999
#
# Weights at Hidden node 2 :: -0.07006383696568318 0.1 0.4299361630343172
#
# Bias weight at Output node::  2.4378636445261783
# Bias weight at Hidden node  1 ::  -0.3652500365993001
# Bias weight at Hidden node  2 ::  0.4299361630343172
#
#
# EPOCH- 344
# Error= 0.0010693953019275861
# Weights at Output node:: 0.4531910731558186 1.1213887986709725
#
# Weights at Hidden node 1 :: 0.23484980149295454 0.4 -0.4651501985070456
#
# Weights at Hidden node 2 :: -0.06983221323139904 0.1 0.43016778676860135
#
# Bias weight at Output node::  2.4388261002979132
# Bias weight at Hidden node  1 ::  -0.3651501985070458
# Bias weight at Hidden node  2 ::  0.43016778676860135
#
#
# EPOCH- 345
# Error= 0.0010658698938933507
# Weights at Output node:: 0.4535319881163036 1.1220487271782442
#
# Weights at Hidden node 1 :: 0.23494939423034406 0.4 -0.46505060576965607
#
# Weights at Hidden node 2 :: -0.06960127701833604 0.1 0.4303987229816643
#
# Bias weight at Output node::  2.4397853832024174
# Bias weight at Hidden node  1 ::  -0.36505060576965626
# Bias weight at Hidden node  2 ::  0.4303987229816643
#
#
# EPOCH- 346
# Error= 0.0010623665466241907
# Weights at Output node:: 0.4538718479889155 1.1227066287918905
#
# Weights at Hidden node 1 :: 0.23504874287770025 0.4 -0.4649512571222999
#
# Weights at Hidden node 2 :: -0.06937102439105733 0.1 0.43062897560894303
#
# Bias weight at Output node::  2.440741513094379
# Bias weight at Hidden node  1 ::  -0.3649512571223001
# Bias weight at Hidden node  2 ::  0.43062897560894303
#
#
# EPOCH- 347
# Error= 0.0010588850579378558
# Weights at Output node:: 0.45421065918184034 1.123362515657351
#
# Weights at Hidden node 1 :: 0.235147848689961 0.4 -0.46485215131003915
#
# Weights at Hidden node 2 :: -0.06914145144746989 0.1 0.4308585485525305
#
# Bias weight at Output node::  2.4416945096465232
# Bias weight at Hidden node  1 ::  -0.36485215131003934
# Bias weight at Hidden node  2 ::  0.4308585485525305
#
#
# EPOCH- 348
# Error= 0.0010554252280861021
# Weights at Output node:: 0.45454842804566636 1.124016399812253
#
# Weights at Hidden node 1 :: 0.235246712912274 0.4 -0.4647532870877261
#
# Weights at Hidden node 2 :: -0.06891255431845088 0.1 0.4310874456815495
#
# Bias weight at Output node::  2.442644392351801
# Bias weight at Hidden node  1 ::  -0.3647532870877263
# Bias weight at Hidden node  2 ::  0.4310874456815495
#
#
# EPOCH- 349
# Error= 0.0010519868597183917
# Weights at Output node:: 0.4548851608740675 1.1246682931876766
#
# Weights at Hidden node 1 :: 0.23534533678009883 0.4 -0.4646546632199013
#
# Weights at Hidden node 2 :: -0.06868432916747906 0.1 0.4313156708325213
#
# Bias weight at Output node::  2.4435911805255475
# Bias weight at Hidden node  1 ::  -0.3646546632199015
# Bias weight at Hidden node  2 ::  0.4313156708325213
#
#
# EPOCH- 350
# Error= 0.001048569757846334
# Weights at Output node:: 0.45522086390447664 1.125318207609402
#
# Weights at Hidden node 1 :: 0.23544372151930762 0.4 -0.4645562784806925
#
# Weights at Hidden node 2 :: -0.06845677219027142 0.1 0.431543227809729
#
# Bias weight at Output node::  2.444534893307609
# Bias weight at Hidden node  1 ::  -0.36455627848069266
# Bias weight at Hidden node  2 ::  0.431543227809729
#
#
# EPOCH- 351
# Error= 0.0010451737298087284
# Weights at Output node:: 0.45555554331874937 1.1259661547991373
#
# Weights at Hidden node 1 :: 0.23554186834628446 0.4 -0.46445813165371563
#
# Weights at Hidden node 2 :: -0.06822987961442481 0.1 0.4317701203855756
#
# Bias weight at Output node::  2.445475549664437
# Bias weight at Hidden node  1 ::  -0.3644581316537158
# Bias weight at Hidden node  2 ::  0.4317701203855756
#
#
# EPOCH- 352
# Error= 0.0010417985852371966
# Weights at Output node:: 0.45588920524381754 1.12661214637573
#
# Weights at Hidden node 1 :: 0.23563977846802353 0.4 -0.4643602215319766
#
# Weights at Hidden node 2 :: -0.06800364769906253 0.1 0.4319963523009379
#
# Bias weight at Output node::  2.4464131683911505
# Bias weight at Hidden node  1 ::  -0.3643602215319768
# Bias weight at Hidden node  2 ::  0.4319963523009379
#
#
# EPOCH- 353
# Error= 0.0010384441360224853
# Weights at Output node:: 0.4562218557523336 1.1272561938563597
#
# Weights at Hidden node 1 :: 0.23573745308222593 0.4 -0.4642625469177742
#
# Weights at Hidden node 2 :: -0.06777807273448576 0.1 0.43222192726551467
#
# Bias weight at Output node::  2.4473477681135707
# Bias weight at Hidden node  1 ::  -0.3642625469177744
# Bias weight at Hidden node  2 ::  0.43222192726551467
#
#
# EPOCH- 354
# Error= 0.0010351101962812364
# Weights at Output node:: 0.45655350086330554 1.1278983086577152
#
# Weights at Hidden node 1 :: 0.23583489337739538 0.4 -0.46416510662260474
#
# Weights at Hidden node 2 :: -0.06755315104182985 0.1 0.4324468489581706
#
# Bias weight at Output node::  2.448279367290224
# Bias weight at Hidden node  1 ::  -0.36416510662260493
# Bias weight at Hidden node  2 ::  0.4324468489581706
#
#
# EPOCH- 355
# Error= 0.0010317965823234984
# Weights at Output node:: 0.4568841465427225 1.128538502097153
#
# Weights at Hidden node 1 :: 0.23593210053293245 0.4 -0.46406789946706767
#
# Weights at Hidden node 2 :: -0.06732887897272526 0.1 0.4326711210272752
#
# Bias weight at Output node::  2.449207984214315
# Bias weight at Hidden node  1 ::  -0.36406789946706786
# Bias weight at Hidden node  2 ::  0.4326711210272752
#
#
# EPOCH- 356
# Error= 0.0010285031126206735
# Weights at Output node:: 0.4572137987041715 1.12917678539384
#
# Weights at Hidden node 1 :: 0.23602907571922785 0.4 -0.4639709242807723
#
# Weights at Hidden node 2 :: -0.06710525290896309 0.1 0.43289474709103737
#
# Bias weight at Output node::  2.4501336370156737
# Bias weight at Hidden node  1 ::  -0.3639709242807725
# Bias weight at Hidden node  2 ::  0.43289474709103737
#
#
# EPOCH- 357
# Error= 0.0010252296077740539
# Weights at Output node:: 0.45754246320944497 1.1298131696698799
#
# Weights at Hidden node 1 :: 0.23612582009775435 0.4 -0.46387417990224583
#
# Weights at Hidden node 2 :: -0.06688226926216531 0.1 0.43311773073783516
#
# Bias weight at Output node::  2.4510563436626702
# Bias weight at Hidden node  1 ::  -0.363874179902246
# Bias weight at Hidden node  2 ::  0.43311773073783516
#
#
# EPOCH- 358
# Error= 0.0010219758904839791
# Weights at Output node:: 0.4578701458691399 1.1304476659514238
#
# Weights at Hidden node 1 :: 0.23622233482115762 0.4 -0.46377766517884256
#
# Weights at Hidden node 2 :: -0.06665992447345932 0.1 0.43334007552654114
#
# Bias weight at Output node::  2.4519761219641056
# Bias weight at Hidden node  1 ::  -0.36377766517884275
# Bias weight at Hidden node  2 ::  0.43334007552654114
#
#
# EPOCH- 359
# Error= 0.0010187417855193903
# Weights at Output node:: 0.4581968524432481 1.1310802851697643
#
# Weights at Hidden node 1 :: 0.2363186210333459 0.4 -0.4636813789666543
#
# Weights at Hidden node 2 :: -0.06643821501315704 0.1 0.4335617849868434
#
# Bias weight at Output node::  2.452892989571073
# Bias weight at Hidden node  1 ::  -0.3636813789666545
# Bias weight at Hidden node  2 ::  0.4335617849868434
#
#
# EPOCH- 360
# Error= 0.0010155271196880368
# Weights at Output node:: 0.4585225886417384 1.1317110381624151
#
# Weights at Hidden node 1 :: 0.23641467986957845 0.4 -0.46358532013042175
#
# Weights at Hidden node 2 :: -0.06621713738043825 0.1 0.43378286261956217
#
# Bias weight at Output node::  2.453806963978792
# Bias weight at Hidden node  1 ::  -0.36358532013042194
# Bias weight at Hidden node  2 ::  0.43378286261956217
#
#
# EPOCH- 361
# Error= 0.001012331721807099
# Weights at Output node:: 0.45884736012513005 1.132339935674174
#
# Weights at Hidden node 1 :: 0.23651051245655305 0.4 -0.46348948754344715
#
# Weights at Hidden node 2 :: -0.06599668810303824 0.1 0.4340033118969622
#
# Bias weight at Output node::  2.4547180625284186
# Bias weight at Hidden node  1 ::  -0.36348948754344734
# Bias weight at Hidden node  2 ::  0.4340033118969622
#
#
# EPOCH- 362
# Error= 0.0010091554226743934
# Weights at Output node:: 0.4591711725050583 1.1329669883581717
#
# Weights at Hidden node 1 :: 0.2366061199124922 0.4 -0.463393880087508
#
# Weights at Hidden node 2 :: -0.06577686373693968 0.1 0.43422313626306075
#
# Bias weight at Output node::  2.4556263024088256
# Bias weight at Hidden node  1 ::  -0.36339388008750817
# Bias weight at Hidden node  2 ::  0.43422313626306075
#
#
# EPOCH- 363
# Error= 0.0010059980550399911
# Weights at Output node:: 0.4594940313448319 1.1335922067769069
#
# Weights at Hidden node 1 :: 0.23670150334722842 0.4 -0.46329849665277173
#
# Weights at Hidden node 2 :: -0.06555766086606857 0.1 0.4344423391339319
#
# Bias weight at Output node::  2.4565317006583616
# Bias weight at Hidden node  1 ::  -0.3632984966527719
# Bias weight at Hidden node  2 ::  0.4344423391339319
#
#
# EPOCH- 364
# Error= 0.0010028594535784056
# Weights at Output node:: 0.45981594215998267 1.1342156014032647
#
# Weights at Hidden node 1 :: 0.23679666386228834 0.4 -0.4632033361377118
#
# Weights at Hidden node 2 :: -0.06533907610199428 0.1 0.43466092389800615
#
# Bias weight at Output node::  2.457434274166582
# Bias weight at Hidden node  1 ::  -0.363203336137712
# Bias weight at Hidden node  2 ::  0.43466092389800615
#
#
# EPOCH- 365
# Error= 0.0009997394548611205
